# %% [markdown]
# ## 4th assignment NLP - Part B - Aris Tsilifonis mtn2323

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Question 2: Replace Tanh activation function of MLP's hidden layers and compare results
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As it can be observed, only 2 lines were adjusted (58,69) inside BISTParser (model.py file).
#
# Measures:
# las 92.37 uas 93.76.
#
# These scores are around 0.1-0.2 better than the ones of B2 experiment. Also, they are significantly better than the ones of transition based parser, since only 89.10 uas was achieved on the previous part (A). The perfomance is calcuated by --do_eval argument (next cell)

# %%
os.chdir('/content/drive/MyDrive/Assignment-4-DependencyParsing/Q_B3')
# !python main.py --n_lstm_layers 1
# Out:
# 2024-06-19 01:47:14,819 - INFO - Experiment Parameters -
# {'train_path': 'data/train.conll', 'dev_path': 'data/dev.conll', 'test_path': 'data/test.conll', 'ds_name': 'ptb', 'model_dir': None, 'ext_emb': None, 'seed': 1234, 'epochs': 5, 'lr': 0.001, 'alpha': 0.25, 'w_emb_dim': 100, 'pos_emb_dim': 25, 'lstm_hid_dim': 125, 'mlp_hid_dim': 100, 'n_lstm_layers': 1, 'no_cuda': False, 'log_interval': 2000, 'do_eval': False, 'experiment_dir': './results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_19_2024'}
# 2024-06-19 01:47:18,173 - INFO - Vocab statistics: words - 34327 | relations - 40 | POS tags - 19
# 2024-06-19 01:47:32,847 - INFO - -----------+-----------+-----------+-----------+-----------
# 2024-06-19 01:47:32,847 - INFO - Train epoch: 1
# 2024-06-19 01:47:33,098 - INFO - [0/39832 (0%)]
# 2024-06-19 01:50:47,290 - INFO - [2000/39832 (5%)]
# 2024-06-19 01:54:10,419 - INFO - [4000/39832 (10%)]
# ...

# %%
# !python main.py --n_lstm_layers 1 --do_eval --model_dir "/content/drive/MyDrive/Assignment-4-DependencyParsing/Q_B3/results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_19_2024"
# Out:
# 2024-06-19 07:40:39,049 - INFO - Experiment Parameters -
# {'train_path': 'data/train.conll', 'dev_path': 'data/dev.conll', 'test_path': 'data/test.conll', 'ds_name': 'ptb', 'model_dir': '/content/drive/MyDrive/Assignment-4-DependencyParsing/Q_B3/results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_19_2024', 'ext_emb': None, 'seed': 1234, 'epochs': 5, 'lr': 0.001, 'alpha': 0.25, 'w_emb_dim': 100, 'pos_emb_dim': 25, 'lstm_hid_dim': 125, 'mlp_hid_dim': 100, 'n_lstm_layers': 1, 'no_cuda': False, 'log_interval': 2000, 'do_eval': True, 'experiment_dir': '/content/drive/MyDrive/Assignment-4-DependencyParsing/Q_B3/results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_19_2024'}
# 2024-06-19 07:40:39,081 - INFO - Vocab statistics: words - 34327 | relations - 40 | POS tags - 19
# ...
