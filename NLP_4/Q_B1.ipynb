# %% [markdown]
# ## 4th assignment NLP Part B - Question 2 - Aris Tsilifonis mtn 2323

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Β. GRAPH-BASED DEPENDENCY PARSER
#
# The given code implements a graph-based dependency parser based on the work of [Kiperwasser and Goldberg (2016) ](https://transacl.org/ojs/index.php/tacl/article/viewFile/885/198). The model consists of a biderectional LSTM encoder. Two MLPs are utilized for two different goals. The first one detects the type of the dependency while the second one measures the confidence (score) of the dependency. Several changes inside the model as well as BERT encoder are leveraged to improve the perfomance of the parser.

# %% [markdown]
# We execute main.py with --n_lstm_layers 1 as argument since encoder should have only one layer of BiLSTM. Also, the arguments --do_eval --model_dir "path_to_trained_model" are required to examine the performance on the test dataset.

# %% [markdown]
# The experiments require 5 training epochs. The las and uas evaluation metrics are illustrating the ability of the model to make correct predictions.
# las: 92.07
# uas: 93.55
#
# The uas score is significantly better than the best scores of the original transition-based dependency parser (Q1, Q4 uas: 89.09). In conclustion, graph based model is preferred.

# %%
os.chdir('/content/drive/MyDrive/Assignment-4-DependencyParsing/B')
# !python main.py --n_lstm_layers 1
# Out:
# 2024-06-18 16:31:23,806 - INFO - Experiment Parameters -
# {'train_path': 'data/train.conll', 'dev_path': 'data/dev.conll', 'test_path': 'data/test.conll', 'ds_name': 'ptb', 'model_dir': None, 'ext_emb': None, 'seed': 1234, 'epochs': 5, 'lr': 0.001, 'alpha': 0.25, 'w_emb_dim': 100, 'pos_emb_dim': 25, 'lstm_hid_dim': 125, 'mlp_hid_dim': 100, 'n_lstm_layers': 1, 'no_cuda': False, 'log_interval': 2000, 'do_eval': False, 'experiment_dir': './results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_18_2024'}
# 2024-06-18 16:31:27,952 - INFO - Vocab statistics: words - 34327 | relations - 40 | POS tags - 19
# 2024-06-18 16:31:42,445 - INFO - -----------+-----------+-----------+-----------+-----------
# 2024-06-18 16:31:42,445 - INFO - Train epoch: 1
# 2024-06-18 16:31:44,700 - INFO - [0/39832 (0%)]
# 2024-06-18 16:33:44,127 - INFO - [2000/39832 (5%)]
# 2024-06-18 16:35:35,620 - INFO - [4000/39832 (10%)]
# ...

# %%
# !python main.py --n_lstm_layers 1 --do_eval --model_dir "/content/drive/MyDrive/Assignment-4-DependencyParsing/B/results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_17_2024"
# Out:
# 2024-06-18 20:27:21,684 - INFO - Experiment Parameters -
# {'train_path': 'data/train.conll', 'dev_path': 'data/dev.conll', 'test_path': 'data/test.conll', 'ds_name': 'ptb', 'model_dir': '/content/drive/MyDrive/Assignment-4-DependencyParsing/B/results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_17_2024', 'ext_emb': None, 'seed': 1234, 'epochs': 5, 'lr': 0.001, 'alpha': 0.25, 'w_emb_dim': 100, 'pos_emb_dim': 25, 'lstm_hid_dim': 125, 'mlp_hid_dim': 100, 'n_lstm_layers': 1, 'no_cuda': False, 'log_interval': 2000, 'do_eval': True, 'experiment_dir': '/content/drive/MyDrive/Assignment-4-DependencyParsing/B/results/ds=ptb_epochs=5_lr=0.001_seed=1234_extEmb=False_wDim=100_pDim=25_lstmDim=125_mlpDim=100_lstmN=1_date=06_17_2024'}
# 2024-06-18 20:27:21,733 - INFO - Vocab statistics: words - 34327 | relations - 40 | POS tags - 19
# 2024-06-18 20:28:05,681 - INFO - -----------+-----------+-----------+-----------+-----------
# ...
